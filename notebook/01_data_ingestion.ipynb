# %%
import pandas as pd
from pathlib import Path
rd = Path.cwd().parent/'data'/'raw'

# %%
#CSV1
csv1 = pd.read_csv(rd/"01_fund_master.csv")
print(csv1.head(10))
print(csv1.shape)
print(csv1.dtypes)
# Out:
#    amfi_code        fund_house  \
# 0     119551   SBI Mutual Fund
# 1     119552   SBI Mutual Fund
# 2     119598   SBI Mutual Fund
# 3     119599   SBI Mutual Fund
# 4     119120   SBI Mutual Fund
# 5     100016  HDFC Mutual Fund
# 6     125497  HDFC Mutual Fund
# 7     100033  HDFC Mutual Fund
# 8     125498  HDFC Mutual Fund
# 9     100025  HDFC Mutual Fund
#
#                                          scheme_name category    sub_category  \
# 0          SBI Bluechip Fund - Regular Plan - Growth   Equity       Large Cap
# 1           SBI Bluechip Fund - Direct Plan - Growth   Equity       Large Cap
# 2         SBI Small Cap Fund - Regular Plan - Growth   Equity       Small Cap
# 3          SBI Small Cap Fund - Direct Plan - Growth   Equity       Small Cap
# 4       SBI Magnum Gilt Fund - Regular Plan - Growth     Debt            Gilt
# 5          HDFC Top 100 Fund - Regular Plan - Growth   Equity       Large Cap
# ...

# %%
# Out:
#    amfi_code        fund_house  \
# 0     119551   SBI Mutual Fund
# 1     119552   SBI Mutual Fund
# 2     119598   SBI Mutual Fund
# 3     119599   SBI Mutual Fund
# 4     119120   SBI Mutual Fund
# 5     100016  HDFC Mutual Fund
# 6     125497  HDFC Mutual Fund
# 7     100033  HDFC Mutual Fund
# 8     125498  HDFC Mutual Fund
# 9     100025  HDFC Mutual Fund
#
#                                          scheme_name category    sub_category  \
# 0          SBI Bluechip Fund - Regular Plan - Growth   Equity       Large Cap
# 1           SBI Bluechip Fund - Direct Plan - Growth   Equity       Large Cap
# 2         SBI Small Cap Fund - Regular Plan - Growth   Equity       Small Cap
# 3          SBI Small Cap Fund - Direct Plan - Growth   Equity       Small Cap
# 4       SBI Magnum Gilt Fund - Regular Plan - Growth     Debt            Gilt
# 5          HDFC Top 100 Fund - Regular Plan - Growth   Equity       Large Cap
# ...

# %%
#CSV2
csv2 = pd.read_csv(rd/"02_nav_history.csv")
print(csv2.shape)
print(csv2.dtypes)
print(csv2.head(10))
# Out:
# (46000, 3)
# amfi_code      int64
# date             str
# nav          float64
# dtype: object
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692
# 5     119551  2022-01-10  55.2835
# 6     119551  2022-01-11  56.0878
# 7     119551  2022-01-12  56.4978
# 8     119551  2022-01-13  56.2934
# 9     119551  2022-01-14  56.5926

# %%
#CSV3
csv3 = pd.read_csv(rd/"03_aum_by_fund_house.csv")
print(csv3.shape)
print(csv3.dtypes)
print(csv3.head(10))
# Out:
# (90, 5)
# date                  str
# fund_house            str
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
#          date                fund_house  aum_lakh_crore  aum_crore  \
# 0  2022-03-31           SBI Mutual Fund            6.05     605000
# 1  2022-03-31       ICICI Prudential MF            4.65     465000
# 2  2022-03-31          HDFC Mutual Fund            4.35     435000
# 3  2022-03-31           Nippon India MF            2.70     270000
# 4  2022-03-31         Kotak Mahindra MF            2.70     270000
# 5  2022-03-31  Aditya Birla Sun Life MF            2.78     278000
# 6  2022-03-31          Axis Mutual Fund            2.50     250000
# 7  2022-03-31           UTI Mutual Fund            2.30     230000
# 8  2022-03-31            Mirae Asset MF            1.05     105000
# 9  2022-03-31           DSP Mutual Fund            1.10     110000
#
#    num_schemes
# 0          186
# 1          216
# 2          195
# ...

# %%
#CSV4
csv4 = pd.read_csv(rd/"04_monthly_sip_inflows.csv")
print(csv4.shape)
print(csv4.dtypes)
print(csv4.head(10))
# Out:
# (48, 6)
# month                            str
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
# 5  2022-06             12276                       5.60
# 6  2022-07             12140                       5.65
# 7  2022-08             12694                       5.71
# 8  2022-09             12976                       5.80
# 9  2022-10             13040                       5.93
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# ...

# %%
#CSV5
csv5 = pd.read_csv(rd/"05_category_inflows.csv")
print(csv5.shape)
print(csv5.dtypes)
print(csv5.head(10))
# Out:
# (144, 3)
# month                   str
# category                str
# net_inflow_crore    float64
# dtype: object
#      month           category  net_inflow_crore
# 0  2024-04          Large Cap            2413.0
# 1  2024-04            Mid Cap            3897.0
# 2  2024-04          Small Cap            3533.0
# 3  2024-04          Flexi Cap            4947.0
# 4  2024-04    Large & Mid Cap            4214.0
# 5  2024-04               ELSS             466.0
# 6  2024-04       Value/Contra            1328.0
# 7  2024-04  Sectoral/Thematic            8052.0
# 8  2024-04             Liquid           37537.0
# 9  2024-04     Short Duration            4400.0

# %%
#CSV6
csv6 = pd.read_csv(rd/"06_industry_folio_count.csv")
print(csv6.shape)
print(csv6.dtypes)
print(csv6.head(10))
# Out:
# (21, 6)
# month                      str
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
# 5  2023-04               15.54                10.88               2.18
# 6  2023-07               16.28                11.40               2.28
# 7  2023-10               16.72                11.70               2.34
# 8  2024-01               17.78                12.45               2.49
# ...

# %%
#CSV7
csv7 = pd.read_csv(rd/"07_scheme_performance.csv")
print(csv7.shape)
print(csv7.dtypes)
print(csv7.head(10))
# Out:
# (40, 19)
# amfi_code               int64
# scheme_name               str
# fund_house                str
# category                  str
# plan                      str
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade                str
# dtype: object
#    amfi_code                                        scheme_name  \
# 0     119551          SBI Bluechip Fund - Regular Plan - Growth
# 1     119552           SBI Bluechip Fund - Direct Plan - Growth
# 2     119598         SBI Small Cap Fund - Regular Plan - Growth
# 3     119599          SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
#CSV8
csv8 = pd.read_csv(rd/"08_investor_transactions.csv")
print(csv8.shape)
print(csv8.dtypes)
print(csv8.head(10))
# Out:
# (32778, 13)
# investor_id               str
# transaction_date          str
# amfi_code               int64
# transaction_type          str
# amount_inr              int64
# state                     str
# city                      str
# city_tier                 str
# age_group                 str
# gender                    str
# annual_income_lakh    float64
# payment_mode              str
# kyc_status                str
# dtype: object
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
# 5   INV001497       2024-01-01     101208              SIP        3295
# ...

# %%
#CSV9
csv9 = pd.read_csv(rd/"09_portfolio_holdings.csv")
print(csv9.shape)
print(csv9.dtypes)
print(csv9.head(10))
# Out:
# (322, 8)
# amfi_code              int64
# stock_symbol             str
# stock_name               str
# sector                   str
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date           str
# dtype: object
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
# 5     119551         NTPC                  NTPC Ltd    Utilities        7.48
# 6     119551     DIVISLAB       Divi's Laboratories       Pharma        3.21
# 7     119551   BHARTIARTL         Bharti Airtel Ltd      Telecom       13.94
# ...

# %%
#CSV10
csv10 = pd.read_csv(rd/"10_benchmark_indices.csv")
print(csv10.shape)
print(csv10.dtypes)
print(csv10.head(10))
# Out:
# (8050, 3)
# date               str
# index_name         str
# close_value    float64
# dtype: object
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15
# 5  2022-01-10    NIFTY50     18124.84
# 6  2022-01-11    NIFTY50     18256.96
# 7  2022-01-12    NIFTY50     18162.54
# 8  2022-01-13    NIFTY50     18179.05
# 9  2022-01-14    NIFTY50     17971.75
