# %%
from pathlib import Path
import pandas as pd
from sqlalchemy import create_engine
rd = Path.cwd()/'data'/'processed'

# %%
mapped = {
    "clean_fund.csv": "dim_fund",
    "clean_performance.csv": "fact_performance",
    "clean_transactions.csv": "fact_transactions",
    "clean_nav.csv": "fact_nav",
    "clean_aum.csv": "fact_aum",
    "clean_sip.csv": "fact_sip",
    "clean_category.csv": "fact_category",
    "clean_industry.csv": "fact_industry",
    "clean_portfoilio.csv": "fact_portfolios",
    "clean_benchmark.csv": "fact_benchmarks"
}

# %%
engine = create_engine('sqlite:///bluestock_mf.db')

# %%
for name,table in mapped.items():
    path = rd/name
    print(path,'-->',name)
    df = pd.read_csv(path)
    df.to_sql(table, engine, index=False)
# Out:
# /home/yash/Projects/bluestock_mf/data/processed/clean_fund.csv --> clean_fund.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_performance.csv --> clean_performance.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_transactions.csv --> clean_transactions.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_nav.csv --> clean_nav.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_aum.csv --> clean_aum.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_sip.csv --> clean_sip.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_category.csv --> clean_category.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_industry.csv --> clean_industry.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_portfoilio.csv --> clean_portfoilio.csv
# /home/yash/Projects/bluestock_mf/data/processed/clean_benchmark.csv --> clean_benchmark.csv
